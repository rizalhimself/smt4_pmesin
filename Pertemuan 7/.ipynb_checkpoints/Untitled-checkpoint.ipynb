# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
 df = pd.read_csv('kc_house_data.csv', usecols=['bedrooms', 'bathrooms', 'sqft_living', 'grade', 'price',
'yr_built'])

# %%
 df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  grade  yr_built
# 0  221900.0         3       1.00         1180      7      1955
# 1  538000.0         3       2.25         2570      7      1951
# 2  180000.0         2       1.00          770      6      1933
# 3  604000.0         4       3.00         1960      7      1965
# 4  510000.0         3       2.00         1680      8      1987

# %%
 df.shape
# Out:
# (21613, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 6 columns):
# price          21613 non-null float64
# bedrooms       21613 non-null int64
# bathrooms      21613 non-null float64
# sqft_living    21613 non-null int64
# grade          21613 non-null int64
# yr_built       21613 non-null int64
# dtypes: float64(2), int64(4)
# memory usage: 1013.2 KB

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living         grade  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   5.400881e+05      3.369454      1.749734   2079.899736      7.656873
# std    3.671272e+05      0.907964      0.734873    918.440897      1.175459
# min    7.500000e+04      0.000000      0.000000    290.000000      1.000000
# 25%    3.219500e+05      3.000000      1.000000   1427.000000      7.000000
# 50%    4.500000e+05      3.000000      2.000000   1910.000000      7.000000
# 75%    6.450000e+05      4.000000      2.000000   2550.000000      8.000000
# max    7.700000e+06     11.000000      8.000000  13540.000000     13.000000
#
#            yr_built
# count  21613.000000
# mean    1971.005136
# std       29.373411
# min     1900.000000
# 25%     1951.000000
# 50%     1975.000000
# 75%     1997.000000
# max     2015.000000

# %%
df['bathrooms'] = df['bathrooms'].astype('int')

# %%
df['bedrooms'] = df['bedrooms'].replace(33,3)

# %%
 df.isnull().sum()
# Out:
# price          0
# bedrooms       0
# bathrooms      0
# sqft_living    0
# grade          0
# yr_built       0
# dtype: int64

# %%
 df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  grade  yr_built
# 0  221900.0         3          1         1180      7      1955
# 1  538000.0         3          2         2570      7      1951
# 2  180000.0         2          1          770      6      1933
# 3  604000.0         4          3         1960      7      1965
# 4  510000.0         3          2         1680      8      1987

# %%
 f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
sns.countplot(df['bedrooms'])
f.add_subplot(1,2,2)
plt.boxplot(df['bedrooms'])
plt.show()

# %%
 f = plt.figure(figsize=(12,4))
f.add_subplot(1,3,1)
sns.countplot(df['bathrooms'])
f.add_subplot(1,3,2)
df['bathrooms'].plot(kind='kde')
f.add_subplot(1,3,3)
plt.boxplot(df['bathrooms'])
plt.show()

# %%
 f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
df['sqft_living'].plot(kind='kde')
f.add_subplot(1,2,2)
plt.boxplot(df['sqft_living'])
plt.show()

# %%
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
sns.countplot(df['grade'])
f.add_subplot(1,2,2)
plt.boxplot(df['grade'])
plt.show()

# %%
 f = plt.figure(figsize=(20,8))
f.add_subplot(1,2,1)
sns.countplot(df['yr_built'])
f.add_subplot(1,2,2)
plt.boxplot(df['yr_built'])
plt.show()

# %%
plt.figure(figsize=(10,8))

sns.pairplot(data=df, x_vars=['bedrooms', 'bathrooms', 'sqft_living', 'grade', 'yr_built'], y_vars=['price'], size=5, aspect=0.75)
plt.show()

# %%
df.corr().style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow0_col0 {
#             background-color:  #023858;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow0_col1 {
#             background-color:  #dfddec;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow0_col2 {
#             background-color:  #eae6f1;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow0_col3 {
#             background-color:  #549cc7;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow0_col4 {
#             background-color:  #7eadd1;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow0_col5 {
#             background-color:  #fff7fb;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow1_col0 {
#             background-color:  #c8cde4;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow1_col1 {
#             background-color:  #023858;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow1_col2 {
#             background-color:  #f2ecf5;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow1_col3 {
#             background-color:  #9cb9d9;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow1_col4 {
#             background-color:  #fff7fb;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow1_col5 {
#             background-color:  #eee9f3;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow2_col0 {
#             background-color:  #7bacd1;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow2_col1 {
#             background-color:  #a4bcda;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow2_col2 {
#             background-color:  #023858;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow2_col3 {
#             background-color:  #589ec8;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow2_col4 {
#             background-color:  #a4bcda;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow2_col5 {
#             background-color:  #9cb9d9;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow3_col0 {
#             background-color:  #1e80b8;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow3_col1 {
#             background-color:  #6da6cd;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow3_col2 {
#             background-color:  #81aed2;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow3_col3 {
#             background-color:  #023858;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow3_col4 {
#             background-color:  #358fc0;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow3_col5 {
#             background-color:  #c6cce3;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow4_col0 {
#             background-color:  #2c89bd;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow4_col1 {
#             background-color:  #d1d2e6;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow4_col2 {
#             background-color:  #bdc8e1;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow4_col3 {
#             background-color:  #2c89bd;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow4_col4 {
#             background-color:  #023858;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow4_col5 {
#             background-color:  #96b6d7;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow5_col0 {
#             background-color:  #fff7fb;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow5_col1 {
#             background-color:  #fff7fb;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow5_col2 {
#             background-color:  #fff7fb;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow5_col3 {
#             background-color:  #fff7fb;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow5_col4 {
#             background-color:  #ece7f2;
#         }    #T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow5_col5 {
#             background-color:  #023858;
#         }</style>
# <table id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3d" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >price</th>
#         <th class="col_heading level0 col1" >bedrooms</th>
#         <th class="col_heading level0 col2" >bathrooms</th>
#         <th class="col_heading level0 col3" >sqft_living</th>
#         <th class="col_heading level0 col4" >grade</th>
#         <th class="col_heading level0 col5" >yr_built</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3dlevel0_row0" class="row_heading level0 row0" >price</th>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow0_col0" class="data row0 col0" >1</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow0_col1" class="data row0 col1" >0.32</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow0_col2" class="data row0 col2" >0.51</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow0_col3" class="data row0 col3" >0.7</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow0_col4" class="data row0 col4" >0.67</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow0_col5" class="data row0 col5" >0.054</td>
#     </tr>    <tr>
#         <th id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3dlevel0_row1" class="row_heading level0 row1" >bedrooms</th>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow1_col0" class="data row1 col0" >0.32</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow1_col1" class="data row1 col1" >1</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow1_col2" class="data row1 col2" >0.48</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow1_col3" class="data row1 col3" >0.59</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow1_col4" class="data row1 col4" >0.37</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow1_col5" class="data row1 col5" >0.16</td>
#     </tr>    <tr>
#         <th id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3dlevel0_row2" class="row_heading level0 row2" >bathrooms</th>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow2_col0" class="data row2 col0" >0.51</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow2_col1" class="data row2 col1" >0.48</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow2_col2" class="data row2 col2" >1</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow2_col3" class="data row2 col3" >0.7</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow2_col4" class="data row2 col4" >0.61</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow2_col5" class="data row2 col5" >0.43</td>
#     </tr>    <tr>
#         <th id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3dlevel0_row3" class="row_heading level0 row3" >sqft_living</th>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow3_col0" class="data row3 col0" >0.7</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow3_col1" class="data row3 col1" >0.59</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow3_col2" class="data row3 col2" >0.7</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow3_col3" class="data row3 col3" >1</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow3_col4" class="data row3 col4" >0.76</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow3_col5" class="data row3 col5" >0.32</td>
#     </tr>    <tr>
#         <th id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3dlevel0_row4" class="row_heading level0 row4" >grade</th>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow4_col0" class="data row4 col0" >0.67</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow4_col1" class="data row4 col1" >0.37</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow4_col2" class="data row4 col2" >0.61</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow4_col3" class="data row4 col3" >0.76</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow4_col4" class="data row4 col4" >1</td>
#         <td id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3drow4_col5" class="data row4 col5" >0.45</td>
#     </tr>    <tr>
#         <th id="T_ee006fc0_a40c_11eb_b565_95e66a31ef3dlevel0_ro

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  grade  yr_built
# 0  221900.0         3          1         1180      7      1955
# 1  538000.0         3          2         2570      7      1951
# 2  180000.0         2          1          770      6      1933
# 3  604000.0         4          3         1960      7      1965
# 4  510000.0         3          2         1680      8      1987

# %%
x = df.drop(columns='price')
y = df['price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=4)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (17290, 5)
# (17290,)
# (4323, 5)
# (4323,)

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(lin_reg.coef_)
print(lin_reg.intercept_)
# Out:
# [-53061.75464279  64658.55790616    188.90926343 131290.89536823
#   -3969.55831454]
# 7031568.245717686

# %%
coef_dict = {
 'features': x.columns,
 'coef_value':lin_reg.coef_
}
coef = pd.DataFrame(coef_dict, columns=['features', 'coef_value'])
coef
# Out:
#       features     coef_value
# 0     bedrooms  -53061.754643
# 1    bathrooms   64658.557906
# 2  sqft_living     188.909263
# 3        grade  131290.895368
# 4     yr_built   -3969.558315

# %%
y_pred = lin_reg.predict(x_test)

# %%
lin_reg.score(x_test, y_test)
# Out:
# 0.612511328694111

# %%
y_prediksi = lin_reg.predict(x_test)
plt.scatter(y_test, y_prediksi)
plt.xlabel('Actual Price')
plt.ylabel('Prediction Price')
plt.show()

# %%
lin_reg.predict([[3,2,1800,7,1990]])
# Out:
# array([361351.99342265])

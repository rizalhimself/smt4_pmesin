# %%
import pandas

# %%
print(pandas.__version__)
# Out:
# 0.23.0

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 0.23.0

# %%
datadata = [['Rizal', 23],['Yusuf', 21],['Gobeng',21]]
df = pd.DataFrame(data,columns=['Name','Age'])
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-46fa2610ada9> in <module>()
#       1 datadata = [['Rizal', 23],['Yusuf', 21],['Gobeng',21]]
# ----> 2 df = pd.DataFrame(data,columns=['Name','Age'])
#       3 print(df)
#
# NameError: name 'data' is not defined

# %%
print(pd.__version__)
# Out:
# 0.23.0

# %%
print(pd.__version__)
# Out:
# 0.23.0

# %%
data = [['Rizal', 23],['Yusuf', 21],['Gobeng',21]]
df = pd.DataFrame(data,columns=['Name','Age'])
print(df)
# Out:
#      Name  Age
# 0   Rizal   23
# 1   Yusuf   21
# 2  Gobeng   21

# %%
data = {
    "Suhu": [30,50,70,100],
    "Keterangan": ['dingin','hangat','agak panas','panas']
}
df= pd.DataFrame(data)
print(df)
# Out:
#    Suhu  Keterangan
# 0    30      dingin
# 1    50      hangat
# 2    70  agak panas
# 3   100       panas

# %%
data = pd.read_csv("data-pmks-bulan-januari-2020.csv")
data
# Out:
#     tanggal_operasi_pmks                jenis_pmks  jumlah_pmks
# 0               1/1/2020            Anak Terlantar            0
# 1               1/1/2020              Anak Jalanan            0
# 2               1/1/2020               Gelandangan            0
# 3               1/1/2020                  Pengemis            0
# 4               1/1/2020                  Pengamen            0
# 5               1/1/2020                  Pemulung            0
# 6               1/1/2020                   Asongan            0
# 7               1/1/2020  Wanita Tuna Susila (WTS)            0
# 8               1/1/2020          Penyandang Cacat            0
# 9               1/1/2020                     Waria            0
# 10              1/1/2020   Korban Tindak Kekerasan            0
# 11              1/1/2020                  Psikotik            0
# 12              1/1/2020           Orang Terlantar            0
# 13              1/1/2020          Lansia Terlantar            0
# ...

# %%
types = data.dtypes
print(types)
# Out:
# tanggal_operasi_pmks    object
# jenis_pmks              object
# jumlah_pmks              int64
# dtype: object

# %%
shape = data.shape
print(shape)
# Out:
# (496, 3)

# %%
peek = data.head(20)
print(peek)
# Out:
#    tanggal_operasi_pmks                jenis_pmks  jumlah_pmks
# 0              1/1/2020            Anak Terlantar            0
# 1              1/1/2020              Anak Jalanan            0
# 2              1/1/2020               Gelandangan            0
# 3              1/1/2020                  Pengemis            0
# 4              1/1/2020                  Pengamen            0
# 5              1/1/2020                  Pemulung            0
# 6              1/1/2020                   Asongan            0
# 7              1/1/2020  Wanita Tuna Susila (WTS)            0
# 8              1/1/2020          Penyandang Cacat            0
# 9              1/1/2020                     Waria            0
# 10             1/1/2020   Korban Tindak Kekerasan            0
# 11             1/1/2020                  Psikotik            0
# 12             1/1/2020           Orang Terlantar            0
# 13             1/1/2020          Lansia Terlantar            0
# ...

# %%
lihat = data.head(3)
print(lihat)
# Out:
#   tanggal_operasi_pmks      jenis_pmks  jumlah_pmks
# 0             1/1/2020  Anak Terlantar            0
# 1             1/1/2020    Anak Jalanan            0
# 2             1/1/2020     Gelandangan            0

# %%
dBaru = pd.read_csv("data-pmks-bulan-januari-2020.csv", skiprows=1, names=[' tanggal_operasi_pmks','jenis_pmks','jumlah_pmks'])
dBaru
# Out:
#      tanggal_operasi_pmks                jenis_pmks  jumlah_pmks
# 0                1/1/2020            Anak Terlantar            0
# 1                1/1/2020              Anak Jalanan            0
# 2                1/1/2020               Gelandangan            0
# 3                1/1/2020                  Pengemis            0
# 4                1/1/2020                  Pengamen            0
# 5                1/1/2020                  Pemulung            0
# 6                1/1/2020                   Asongan            0
# 7                1/1/2020  Wanita Tuna Susila (WTS)            0
# 8                1/1/2020          Penyandang Cacat            0
# 9                1/1/2020                     Waria            0
# 10               1/1/2020   Korban Tindak Kekerasan            0
# 11               1/1/2020                  Psikotik            0
# 12               1/1/2020           Orang Terlantar            0
# ...

# %%
desk = data.describe()
print(desk)
# Out:
#        jumlah_pmks
# count   496.000000
# mean      0.141129
# std       1.494854
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max      32.000000

# %%
korelasi = data.corr(method='pearson')
print(korelasi)
# Out:
#              jumlah_pmks
# jumlah_pmks          1.0
